# %%
import tensorflow as tf
import os

class MyFashionMnist(object):
  def train(self):
  
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
    
    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('장치의 수: {}'.format(strategy.num_replicas_in_sync))      
    x_train, x_test = x_train / 255.0, x_test / 255.0

    with strategy.scope():    
        model = tf.keras.models.Sequential([
          tf.keras.layers.Flatten(input_shape=(28, 28)),
          tf.keras.layers.Dense(128, activation='relu'),
          tf.keras.layers.Dropout(0.2),
          tf.keras.layers.Dense(10, activation='softmax')
        ])
        model.summary()
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

        model.fit(x_train, y_train, epochs=10)

        model.evaluate(x_test,  y_test, verbose=2)

if __name__ == '__main__':
    if os.getenv('FAIRING_RUNTIME', None) is None:
        from kubeflow import fairing
        from kubeflow.fairing.kubernetes import utils as k8s_utils

        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'
        fairing.config.set_builder(
            'append',
            image_name='fairing-job',
            base_image='brightfly/kubeflow-jupyter-lab:tf2.0-gpu',
            registry=DOCKER_REGISTRY, 
            push=True)
        # cpu 2, memory 5GiB
        fairing.config.set_deployer('job',
                                    namespace='dudaji',
                                    pod_spec_mutators=[
                                        k8s_utils.get_resource_mutator(cpu=2,
                                                                       memory=5)]
         
                                   )
        fairing.config.run()
    else:
        remote_train = MyFashionMnist()
        remote_train.train()
# Out:
# [I 200215 14:42:02 config:123] Using preprocessor: <kubeflow.fairing.preprocessors.converted_notebook.ConvertNotebookPreprocessor object at 0x7f65b2937198>
# [I 200215 14:42:02 config:125] Using builder: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7f65b2937748>
# [I 200215 14:42:02 config:127] Using deployer: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7f65b2937748>
# [W 200215 14:42:02 append:50] Building image using Append builder...
# [I 200215 14:42:02 base:105] Creating docker context: /tmp/fairing_context_7iejmqld
# [I 200215 14:42:02 converted_notebook:127] Converting dist-fashion-mnist-fairing-.ipynb to dist-fashion-mnist-fairing-.py
# [I 200215 14:42:02 docker_creds_:234] Loading Docker credentials for repository 'brightfly/kubeflow-jupyter-lab:tf2.0-gpu'
# [W 200215 14:42:05 append:54] Image successfully built in 2.1764135679695755s.
# [W 200215 14:42:05 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/fairing-job:B0244C0F...
# [I 200215 14:42:05 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/fairing-job:B0244C0F'
# [W 200215 14:42:05 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/fairing-job:B0244C0F
# [I 200215 14:42:05 docker_session_:280] Layer sha256:f6490e4900cb64767e994addad4a4329cca4ccfce37a63d21249d89b63ceb478 exists, skipping
# [I 200215 14:42:05 docker_session_:280] Layer sha256:9f0a21d58e5dce5512db6d5595c6e9c4ab014917cf0644e2d282b8f5e3f2522a exists, skipping
# [I 200215 14:42:05 docker_session_:280] Layer sha256
# [W 200215 14:42:05 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/fairing-job:B0244C0F in 0.20229113392997533s.
# [W 200215 14:42:05 job:90] The job fairing-job-fdrp8 launched.
# [W 200215 14:42:05 manager:227] Waiting for fairing-job-fdrp8-hmn6r to start...
# [W 200215 14:42:05 manager:227] Waiting for fairing-job-fdrp8-hmn6r to start...
# [W 200215 14:42:05 manager:227] Waiting for fairing-job-fdrp8-hmn6r to start...
# [W 200215 14:42:06 manager:227] Waiting for fairing-job-fdrp8-hmn6r to start...
# [I 200215 14:42:07 manager:233] Pod started running True
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 2020-02-15 14:42:10.267958: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-15 14:42:10.317828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.319094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-02-15 14:42:10.319261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.320273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:05.0
# 2020-02-15 14:42:10.320612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-02-15 14:42:10.322008: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-02-15 14:42:10.323903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-02-15 14:42:10.324333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-02-15 14:42:10.326426: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-02-15 14:42:10.328015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-02-15 14:42:10.332458: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-15 14:42:10.332594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.333641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.334511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.335356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.336183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1
# 2020-02-15 14:42:10.336802: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-02-15 14:42:10.344355: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-02-15 14:42:10.345012: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562ca10 executing computations on platform Host. Devices:
# 2020-02-15 14:42:10.345059: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2020-02-15 14:42:10.560200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.562835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.564156: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56af280 executing computations on platform CUDA. Devices:
# 2020-02-15 14:42:10.564187: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-02-15 14:42:10.564197: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (1): Tesla K80, Compute Capability 3.7
# 2020-02-15 14:42:10.565077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.566183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-02-15 14:42:10.566290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.567313: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:05.0
# 2020-02-15 14:42:10.567371: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-02-15 14:42:10.567385: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-02-15 14:42:10.567403: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-02-15 14:42:10.567414: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-02-15 14:42:10.567431: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-02-15 14:42:10.567441: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-02-15 14:42:10.567456: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-15 14:42:10.567555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.568561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.569901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.571137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.572070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1
# 2020-02-15 14:42:10.572172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-02-15 14:42:10.574722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-02-15 14:42:10.574754: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1
# 2020-02-15 14:42:10.574766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y
# 2020-02-15 14:42:10.574774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N
# 2020-02-15 14:42:10.574937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.575932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.577146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.578199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10804 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2020-02-15 14:42:10.578814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-15 14:42:10.579835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10804 MB memory) -> physical GPU (device: 1, name: Tesla K80, pci bus id: 0000:00:05.0, compute capability: 3.7)
# 장치의 수: 2
# Traceback (most recent call last):
#   File "/app/dist-fashion-mnist-fairing-.py", line 58, in <module>
#     remote_train.train()
#   File "/app/dist-fashion-mnist-fairing-.py", line 24, in train
#     tf.keras.layers.Dense(10, activation='softmax')
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/sequential.py", line 114, in __init__
#     self.add(layer)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/sequential.py", line 196, in add
#     output_tensor = layer(self.outputs[0])
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 817, in __call__
#     self._maybe_build(inputs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 2141, in _maybe_build
#     self.build(input_shapes)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/core.py", line 1027, in build
#     trainable=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 2311, in __setattr__
#     if val.trainable:
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py", line 477, in trainable
#     raise NotImplementedError
# NotImplementedError
# [W 200215 14:42:12 job:162] Cleaning up job fairing-job-fdrp8...
