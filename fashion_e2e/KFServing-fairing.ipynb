# %%
from kubernetes import client
from kfserving import KFServingClient
from kfserving import constants
from kfserving import utils
from kfserving import V1alpha2EndpointSpec
from kfserving import V1alpha2PredictorSpec
from kfserving import V1alpha2TensorflowSpec
from kfserving import V1alpha2InferenceServiceSpec
from kfserving import V1alpha2InferenceService
from kubernetes.client import V1ResourceRequirements
import os
import sys
import argparse
import logging
import time

'''
'''
class KFServing(object):
    def run(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--namespace', required=False, default='kubeflow')
        # pvc://${PVCNAME}/dir
        parser.add_argument('--storage_uri', required=False, default='/mnt/export')
        parser.add_argument('--name', required=False, default='kfserving-sample')        
        args = parser.parse_args()
        namespace = args.namespace
        serving_name =  args.name
        
        api_version = constants.KFSERVING_GROUP + '/' + constants.KFSERVING_VERSION
        default_endpoint_spec = V1alpha2EndpointSpec(
                                  predictor=V1alpha2PredictorSpec(
                                    tensorflow=V1alpha2TensorflowSpec(
                                      storage_uri=args.storage_uri,
                                      resources=V1ResourceRequirements(
                                          requests={'cpu':'100m','memory':'1Gi'},
                                          limits={'cpu':'100m', 'memory':'1Gi'}))))
        isvc = V1alpha2InferenceService(api_version=api_version,
                                  kind=constants.KFSERVING_KIND,
                                  metadata=client.V1ObjectMeta(
                                      name=serving_name, namespace=namespace),
                                  spec=V1alpha2InferenceServiceSpec(default=default_endpoint_spec))        
        
        KFServing = KFServingClient()
        KFServing.create(isvc)
        print('waiting 5 sec for Creating InferenceService')
        time.sleep(5)
        
        KFServing.get(serving_name, namespace=namespace, watch=True, timeout_seconds=300)
        
if __name__ == '__main__':
    if os.getenv('FAIRING_RUNTIME', None) is None:
        from kubeflow.fairing.builders.append.append import AppendBuilder
        from kubeflow.fairing.preprocessors.converted_notebook import \
            ConvertNotebookPreprocessor

        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'
        base_image = 'brightfly/kubeflow-kfserving:latest'
        image_name = 'kfserving'

        builder = AppendBuilder(
            registry=DOCKER_REGISTRY,
            image_name=image_name,
            base_image=base_image,
            push=True,
            preprocessor=ConvertNotebookPreprocessor(
                notebook_file="KFServing-fairing.ipynb"
            )
        )
        builder.build()
    else:
        serving = KFServing()
        serving.run()
# Out:
# [W 200316 05:33:33 append:50] Building image using Append builder...
# [I 200316 05:33:33 base:105] Creating docker context: /tmp/fairing_context_5jc94lw3
# [I 200316 05:33:33 converted_notebook:127] Converting KFServing-fairing.ipynb to KFServing-fairing.py
# [I 200316 05:33:33 docker_creds_:234] Loading Docker credentials for repository 'brightfly/kubeflow-kfserving:latest'
# [W 200316 05:33:36 append:54] Image successfully built in 2.4861521939965314s.
# [W 200316 05:33:36 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/kfserving:857CCC8F...
# [I 200316 05:33:36 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/kfserving:857CCC8F'
# [W 200316 05:33:36 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/kfserving:857CCC8F
# [I 200316 05:33:36 docker_session_:280] Layer sha256:87b2c33457cb85bf8ea16ce26c1496cdb8d2627237b551c3eeb90a9aa8fd0aed exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:772bb01b5acf1c08f32de033c32c9f807d047164867a11ffdc96669762b29725 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:43bf3e3107f525b7dea5b3cdfd15f62666066202105a0aaddbab2a02aefad1f7 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:59b774443140f464249d4af7a526ecee8c2476bad1e5c5c15d74707b5b2b7227 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:5067aa3d4931716bd5b3473f05f31513fa4a124c03db0a51f6d7baf2a16f700b exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:5bf324b442328ad6fb1825b37923ad8850e8bc148e9cbfbd0971f951f5f12a81 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:d391d47713783ed4de6f856d63d4192240e9c93d782b158284aedc307cbe4fb6 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:ca7e1bbea389949863f72a88b675dd8f888f40a79be6573c1e2f0095335e68ab exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:dcfa0aa1ae2c54d0de4b6ad0ee4d9f795c93368ae7d87801784c1f8ae624ac33 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:a2d410a0f39cff43a6ad7c800424f6c9dad59813cbde66b65f229e04d6655775 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:8f94a3a4572995fbbfcb21a5ad2796af7329e8d90a8bf97f615e14a99d848213 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:d918eaefd9de8a1595f56900fdb8ab65a03d64b1da1078da7c0b0bf6f7552a14 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:8f0fdd3eaac017684c880d836abdaf02f9db7ac8ecca970356482e3d8e315650 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:c513d77460ba16f23ee2eb25f8a99c95b5bd67959caa8d1a95d241c793a0ed05 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:27622921edb2aae9e0cb64f71a81b4a7cfef8f6a6c766514a018815834ba4e14 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:fcb6b3d82de6c9870be99da3b3aba1ee9ae6fd451f58a349297c90d5a12620e1 exists, skipping
# [I 200316 05:33:36 docker_session_:280] Layer sha256:04de2638d2c074bedb4d1195ea9894e67a647b0f076702afce5a9e6f811b0f40 exists, skipping
# [I 200316 05:33:36 docker_session_:284] Layer sha256:bbba0b37c3ae1ed5c6fdb383b8fff210266821f3c31f7ac6a381d6c5bee57676 pushed.
# [I 200316 05:33:36 docker_session_:280] Layer sha256:a667b2dd2f883977fa9a4eb368637cb2e6dc8d1d59407c6a00188a3df8b62e6f exists, skipping
# [I 200316 05:33:36 docker_session_:284] Layer sha256:06a3e2c48964010da6010093c81b302b1508a1dd8f199af49e084570da8b72b4 pushed.
# [I 200316 05:33:36 docker_session_:334] Finished upload of: kubeflow-registry.default.svc.cluster.local:30000/kfserving:857CCC8F
# [W 200316 05:33:36 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/kfserving:857CCC8F in 0.16554978000203846s.
